# %%
from splash_links.client.base import from_uri

links = from_uri("http://localhost:8080")

entity = links.create_entity(entity_type="Person", properties={"name": "Alice"})
print(f"Created entity: {entity.id} of type {entity.entity_type}")

entity2 = links.create_entity(entity_type="Person", properties={"name": "Bob"})

link = links.create_link(
    subject_id=entity,
    predicate="knows",
    object_id=entity2,
)

print(f"Created link: {link.id} ({link.subject_id} {link.predicate} {link.object_id})")
# Out:
# Created entity: 93fce63d-669e-4062-99c8-90065f5374bf of type Person
# Created link: 5866f797-d678-4a32-8a1c-6106415e7ee6 (93fce63d-669e-4062-99c8-90065f5374bf knows c8fc747b-97a1-401a-bc74-7b8a3f924f9c)

# %%
def generated_arrays(tiled_node):
    import numpy as np
    for i in range(5):
        exists = f"array_{i}" in tiled_node
        if not exists:
            yield tiled_node.write_array(np.random.random((100, 100)), key=f"array_{i}")
        else:
            yield tiled_node[f"array_{i}"]

# %%
# Now do tiled client
# from tiled.client import from_uri as tiled_from_uri
scan_id = c['beamlines/bl531/raw'].keys()[-1]
raw = c['beamlines/bl531/raw'][scan_id]['primary']['det_image']
print(raw)
processed_root = c['beamlines/testing']
random_array_nodes = [array_node for array_node in generated_arrays(processed_root)]

processed1 = random_array_nodes[0]
processed2 = random_array_nodes[1]
extra_processed = random_array_nodes[2]

# create_link detects that items are tiled objects and creates entities if not already existing
# and also creates the link between them
raw_to_processed1= links.create_link(processed1, "processed_from", raw)
processed1_to_extra = links.create_link(extra_processed, "custom_processed_from", processed1)
extra_processed_to_processed2 = links.create_link(processed2, "processed_from", raw)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 21
#      19 # find all of processed1 links
#      20 processed1_links = links.find_links(processed1)  # find all links involving processed1
# ---> 21 assert len(processed1_links) == 2  # should have two links
#      23 # find all direct prcocessed items from raw
#      24 processed_from_raw = links.find_links(raw, predicate="processed_from")  # find links with specific predicate
#
# AssertionError:

# %%
from pprint import pprint
# find all of processed1 links
processed1_links = links.find_links(processed1)  # find all links involving processed1
pprint(processed1_links)

# find all dire
# ct prcocessed items from raw
processed_from_raw = links.find_links(raw, predicate="processed_from")  # find links with specific predicate
print(processed_from_raw)
# Out:
# [Link(id='61f16e8d-86ee-46fe-8f79-c9baddfeac11',
#       subject_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1',
#       predicate='processed_from',
#       object_id='705e6042-7043-4a39-a973-2b4c6a50980b',
#       properties=None,
#       created_at='2026-03-13T10:31:45.400226-07:00'),
#  Link(id='b2b0a83e-a5ac-4d9d-9068-40ba2062853b',
#       subject_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1',
#       predicate='processed_from',
#       object_id='705e6042-7043-4a39-a973-2b4c6a50980b',
#       properties=None,
#       created_at='2026-03-13T10:33:52.004858-07:00'),
#  Link(id='7853c573-a048-43c5-ad26-d4c3895e8688',
#       subject_id='def14999-5291-4acb-b2cc-e3d9974e3b04',
#       predicate='custom_processed_from',
#       object_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1',
#       properties=None,
#       created_at='2026-03-13T10:31:45.471381-07:00'),
#  Link(id='66428f01-55eb-4aa4-bb85-580a61f2feba',
#       subject_id='def14999-5291-4acb-b2cc-e3d9974e3b04',
#       predicate='custom_processed_from',
#       object_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1',
#       properties=None,
#       created_at='2026-03-13T10:33:56.429983-07:00')]
# [Link(id='61f16e8d-86ee-46fe-8f79-c9baddfeac11', subject_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1', predicate='processed_from', object_id='705e6042-7043-4a39-a973-2b4c6a50980b', properties=None, created_at='2026-03-13T10:31:45.400226-07:00'), Link(id='b2b0a83e-a5ac-4d9d-9068-40ba2062853b', subject_id='ef3fb360-f776-4a5a-823c-aac7aec75ac1', predicate='processed_from', object_id='705e6042-7043-4a39-a973-2b4c6a50980b', properties=None, created_at='2026-03-13T10:33:52.004858-07:00')]

# %%
# Out:
# <Container {'bl931', 'bl832', 'raw', 'bl531', 'testing'}>
